# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamksingh1/TextClassification/blob/main/Spanish/TestSpanishClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Library

# %%
# install simpletransformers
# !pip install simpletransformers

# %% [markdown]
# ### Load Model

# %%
import os
import tarfile

def unpack_model(model_name=''): 
  tar = tarfile.open(f"{model_name}.tar.gz", "r:gz")
  tar.extractall()
  tar.close()

# %%
unpack_model("/content/drive/My Drive/SpanishModel/eseval-distilbert-spanish")

# %%
from simpletransformers.classification import ClassificationModel

# define hyperparameter
train_args ={"reprocess_input_data": True,
             "overwrite_output_dir": True,
             "fp16":False,
             "num_train_epochs": 4}

# Create a ClassificationModel
model = ClassificationModel(
    "bert", "outputs/",
    num_labels=3,
    args=train_args
)
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.

# %% [markdown]
# ### Predict

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/My Drive/SpanishModel/Tweets_Test.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweet_english  20 non-null     object
#  1   tweet_spanish  20 non-null     object
#  2   sentiment      0 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 608.0+ bytes

# %%
output = []

# %%
class_list = ['neutral','negative','positive']
predictions, raw_outputs = model.predict(df['tweet_spanish'].to_list())

for i in range(len(predictions)):
    output.append(class_list[predictions[i]])

# %%
df['sentiment'] = output

# %%
df
# Out:
#                                         tweet_english  ... sentiment
# 0   I had a very nice experience in my flight back...  ...  positive
# 1   My flight got delayed by 8 hours. This is bad....  ...  negative
# 2   Very good staffs and amazing hospitality. Than...  ...  positive
# 3   Travelling experience was not bad could have b...  ...  positive
# 4            Travelling Pune to Ranchi on @FlightXYZ   ...   neutral
# 5   It was the first flight experience for me. Wel...  ...  positive
# 6   This is one such airline where you cannot expe...  ...  negative
# 7   We were extremely impressed by the one flight ...  ...  positive
# 8   The overall the experience of the flight was f...  ...  negative
# 9   Nice experience in these pandemic times. @Flig...  ...  positive
# 10      On Flight Back to Pune Via Delhi. @FlightXYZ   ...   neutral
# 11   Flight delayed due to bird hit during take of...  ...  negative
# 12   Reached Delhi.Waiting for next flight@FlightXYZ   ...   neutral
# ...

# %%
df.to_csv("/content/drive/My Drive/SpanishModel/Tweets_Test_predicted.csv",index=False)

# %% [markdown]
# ### Predict Cell By Cell

# %%
class_list = ['neutral','negative','positive']

test_tweet = "Tuve una experiencia muy bonita en mi vuelo de regreso a casa. @VueloXYZ"
#I had a very nice experience in my flight back to home. @FlightXYZ

predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
class_list = ['neutral','negative','positive']

test_tweet = "Mi vuelo se retrasó 8 horas. Esto es malo No esperaba esto @FlightXYZ"
#My flight got delayed by 8 hours. This is bad.Not expected this @FlightXYZ

predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 1
# negative

# %%
test_tweet = "Muy buen personal y una hospitalidad increíble. Gracias. @VueloXYZ"
# Very good staffs and amazing hospitality. Thank you. @FlightXYZ

predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
test_tweet = "La experiencia de viaje no fue mala, podría haber sido mejor. @VueloXYZ"
# Travelling experience was not bad could have been better. @FlightXYZ

predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
test_tweet = "Viajando de Pune a Ranchi en @FlightXYZ"
# Travelling Pune to Ranchi on @FlightXYZ

predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 0
# neutral

# %%
test_tweet = "Fue la primera experiencia de vuelo para mí. Bueno, emocionante y un poco de miedo. El vuelo fue bueno en general. @ FlightXYZ"
# It was the first flight experience for me. Well exciting and little bit fear. The flying was overall good.@FlightXYZ

predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
test_tweet ="Esta es una de esas aerolíneas en las que no puede esperar llevar ni un solo KG extra con usted. El espacio para las piernas es menor en comparación con las otras aerolíneas. @ FlightXYZ"
# This is one such airline where you cannot expect to take even a single KG extra with you. Leg space is less as compared to the other airlines.@FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 1
# negative

# %%
test_tweet ="Quedamos muy impresionados con el único vuelo de esta aerolínea. El personal de check-in estuvo extremadamente bien arreglado, agradable y eficiente. @ FlightXYZ"
# We were extremely impressed by the one flight on this airline. The check-in staff were extremely well groomed, pleasant and efficient.@FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
test_tweet ="En general, la experiencia del vuelo estuvo bien, pero el sabor de la comida fue insípido. Definitivamente necesitan trabajar en eso. @VueloXYZ"
# The overall the experience of the flight was fine but the food taste was bland. They definitely need to work on that. @FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 1
# negative

# %%
test_tweet ="Buena experiencia en estos tiempos de pandemia. @VueloXYZ"
# Nice experience in these pandemic times. @FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
test_tweet ="En vuelo de regreso a Pune vía Delhi. @VueloXYZ"
# On Flight Back to Pune Via Delhi. @FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 0
# neutral

# %%
test_tweet ="Vuelo retrasado debido al impacto de un pájaro durante el despegue. Miedo @ FlightXYZ"
# Flight delayed due to bird hit during take off.Scary. @FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 1
# negative

# %%
test_tweet ="Llegó a Delhi Esperando el próximo vuelo @ FlightXYZ"
# Reached Delhi.Waiting for next flight@FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 0
# neutral

# %%
test_tweet ="Buena experiencia, llegó antes de tiempo. @ FlightXYZ"
# Nice experience,Arrived before time.@FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
test_tweet ="El servicio es simplemente patético ... ha pasado 1 mes y les he pedido una resolución de un problema, pero no he ayudado. @VueloXYZ"
# Service is just pathetic.. it's been 1 month I have asked them for a resolution of an issue but no help. @FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 1
# negative

# %%
test_tweet ="Nunca volveré a abordar este vuelo en mi vida y también me aseguraré de que mis amigos y familiares se abstengan de usar @FlightXYZ en el futuro."
# I will never board again in this flight in my life and I will also make sure that my friends and relatives to refrain to use @FlightXYZ in future..
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 1
# negative

# %%
test_tweet ="La peor parte es que mantuvieron la mayoría de los asientos pagados durante el check-in en línea, por lo que tendrá que formar parte de la larga cola en el aeropuerto. @ FlightXYZ"
# The worst part is that they kept most of the seats as paid during online check-in so you will have to part of the long queue at the airport.@FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 1
# negative

# %%
test_tweet ="el piloto y el personal fueron decentes, y el vuelo fue muy suave. @ FlightXYZ"
#the pilot and staff were decent, and the flying was very smooth.@FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive

# %%
test_tweet ="Todas las precauciones de seguridad se tomaron claramente. Me encanta el servicio, seguramente lo recomendaré a todos los amigos y familiares @FlightXYZ"
#All the safety precautions were clearly taken. Love the service, will surely recommend to all friends and family @FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 0
# neutral

# %%
test_tweet ="Los servicios de vuelo fueron impecables y la tripulación muy profesional y agradable.Los asientos eran muy cómodos y la comida era estupenda. Buen trabajo @FlightXYZ"
# The Flight Services were impeccable and the Crew very professional and Nice.The Seats were very comfortable and the Food was Great. Great Job @FlightXYZ
predictions, raw_outputs = model.predict([test_tweet])

print(predictions[0])
print(class_list[predictions[0]])
# Out:
# ...
# 2
# positive
